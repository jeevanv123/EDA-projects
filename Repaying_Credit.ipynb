# %% [markdown]
# # HACKATHON

# %%
import matplotlib.pyplot as plt             
from tabulate import tabulate               
import matplotlib as mat                    
import seaborn as sns                       
import pandas as pd                   
import numpy as np

# %%
data=pd.read_csv("data (2).csv")      #read the data

# %%
data
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0          100002       1         Cash loans      M   N     Y             0
# 1          100003       0         Cash loans      F   N     N             0
# 2          100004       0    Revolving loans      M   Y     Y             0
# 3          100006       0         Cash loans      F   N     Y             0
# 4          100007       0         Cash loans      M   N     Y             0
# ...           ...     ...                ...    ...  ..   ...           ...
# 99995      216086       0         Cash loans      F   N     Y             1
# 99996      216087       0         Cash loans      F   N     Y             1
# 99997      216088       0         Cash loans      F   Y     Y             0
# 99998      216089       0         Cash loans      F   Y     N             0
# 99999      216090       0    Revolving loans      M   Y     Y             0
#
# ...

# %%
data.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'GENDER', 'Car', 'House',
#        'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_GOODS_PRICE',
#        'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'DAYS_EMPLOYED', 'MOBILE', 'WORK_PHONE',
#        'HOME_PHONE', 'MOBILE_REACHABLE', 'FLAG_EMAIL', 'OCCUPATION_TYPE',
#        'CNT_FAM_MEMBERS', 'APPLICATION_DAY', 'TOTAL_DOC_SUBMITTED'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   SK_ID_CURR           100000 non-null  int64
#  1   TARGET               100000 non-null  int64
#  2   NAME_CONTRACT_TYPE   100000 non-null  object
#  3   GENDER               100000 non-null  object
#  4   Car                  100000 non-null  object
#  5   House                100000 non-null  object
#  6   CNT_CHILDREN         100000 non-null  int64
#  7   AMT_INCOME_TOTAL     100000 non-null  float64
#  8   AMT_CREDIT           100000 non-null  float64
#  9   AMT_GOODS_PRICE      99919 non-null   float64
#  10  NAME_TYPE_SUITE      99595 non-null   object
#  11  NAME_INCOME_TYPE     100000 non-null  object
#  12  NAME_EDUCATION_TYPE  100000 non-null  object
#  13  NAME_FAMILY_STATUS   100000 non-null  object
#  14  DAYS_EMPLOYED        100000 non-null  int64
# ...

# %%
data.shape
# Out:
# (100000, 24)

# %%
data.isnull().sum()
# Out:
# SK_ID_CURR                 0
# TARGET                     0
# NAME_CONTRACT_TYPE         0
# GENDER                     0
# Car                        0
# House                      0
# CNT_CHILDREN               0
# AMT_INCOME_TOTAL           0
# AMT_CREDIT                 0
# AMT_GOODS_PRICE           81
# NAME_TYPE_SUITE          405
# NAME_INCOME_TYPE           0
# NAME_EDUCATION_TYPE        0
# NAME_FAMILY_STATUS         0
# DAYS_EMPLOYED              0
# MOBILE                     0
# WORK_PHONE                 0
# HOME_PHONE                 0
# MOBILE_REACHABLE           0
# FLAG_EMAIL                 0
# OCCUPATION_TYPE        31224
# CNT_FAM_MEMBERS            1
# APPLICATION_DAY            0
# TOTAL_DOC_SUBMITTED        0
# dtype: int64

# %%
data.describe()
# Out:
#           SK_ID_CURR         TARGET   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count  100000.000000  100000.000000  100000.000000      1.000000e+05
# mean   158006.140860       0.080930       0.417390      1.694261e+05
# std     33481.166996       0.272729       0.721014      3.835007e+05
# min    100002.000000       0.000000       0.000000      2.565000e+04
# 25%    129076.750000       0.000000       0.000000      1.125000e+05
# 50%    157877.000000       0.000000       0.000000      1.440000e+05
# 75%    186982.250000       0.000000       1.000000      2.025000e+05
# max    216090.000000       1.000000      12.000000      1.170000e+08
#
#          AMT_CREDIT  AMT_GOODS_PRICE  DAYS_EMPLOYED         MOBILE  \
# count  1.000000e+05     9.991900e+04  100000.000000  100000.000000
# mean   5.990034e+05     5.383451e+05   63292.222060       0.999990
# std    4.020520e+05     3.693977e+05  140839.697296       0.003162
# min    4.500000e+04     4.500000e+04  -17531.000000       0.000000
# ...

# %% [markdown]
# # LEVEL 1 ANALYSIS

# %% [markdown]
# We have to seperate the columns as continous or categorical data
# So for this we use nunique function
# We consider columns with more than 50 unique values as continous and others as categorical

# %%
# Seprating out the categorical and continuous variables
def seprate_data_types(data):
    categorical = []
    continuous = []
    for column in data.columns:                # looping on the number of columns
        if data[column].nunique() < 50:       # nunique:  returns unique values in the column,
                                                    #here 100 is the hyperparamter and can be changed
            categorical.append(column)
        else:
            continuous.append(column)
            
    return categorical, continuous 


categorical, continuous = seprate_data_types(data)         # Calling the function

# # Tabulate is a package used to print the list, dict or any data sets in a proper format; in table format
from tabulate import tabulate
table = [categorical, continuous]
print(tabulate({"Categorical":categorical,
                "continuous": continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical          continuous
# -------------------  ----------------
# TARGET               SK_ID_CURR
# NAME_CONTRACT_TYPE   AMT_INCOME_TOTAL
# GENDER               AMT_CREDIT
# Car                  AMT_GOODS_PRICE
# House                DAYS_EMPLOYED
# CNT_CHILDREN
# NAME_TYPE_SUITE
# NAME_INCOME_TYPE
# NAME_EDUCATION_TYPE
# NAME_FAMILY_STATUS
# MOBILE
# WORK_PHONE
# HOME_PHONE
# MOBILE_REACHABLE
# FLAG_EMAIL
# OCCUPATION_TYPE
# CNT_FAM_MEMBERS
# APPLICATION_DAY
# TOTAL_DOC_SUBMITTED

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %% [markdown]
# So we consider the categorical data first
# For categorical data we can find the mode

# %%
def info_of_cat(col): 
    print(f"Unique values in {col} are: {data[col].unique()}") # unique: returns the unique values in the col
    print(f"Mode of {col} is {data[col].mode()[0]}")  # mode: returns the mode of the column
    print(f"Number of missing values in {col} is {data[col].isnull().sum()}") # isnull().sum() counts the number of null in dataframe
    if data[col].isnull().sum() > 0:  #` check if null values are present
        print(f"\nThere are null values in the {col} column")

# %% [markdown]
# ## Coloumn : Target

# %%
info_of_cat("TARGET")
# Out:
# Unique values in TARGET are: [1 0]
# Mode of TARGET is 0
# Number of missing values in TARGET is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of target")                  # Set the title of the graph
percentage = data["TARGET"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(data["TARGET"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = data["TARGET"], ax = ax[0])
plt.pie(percentage, labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## So the target customer are around 92%

# %% [markdown]
# ## Column : NAME_CONTRACT_TYPE

# %%
info_of_cat("NAME_CONTRACT_TYPE")
# Out:
# Unique values in NAME_CONTRACT_TYPE are: ['Cash loans' 'Revolving loans']
# Mode of NAME_CONTRACT_TYPE is Cash loans
# Number of missing values in NAME_CONTRACT_TYPE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of type of loan")                  # Set the title of the graph
percentage = data["NAME_CONTRACT_TYPE"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(data["NAME_CONTRACT_TYPE"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = data["NAME_CONTRACT_TYPE"], ax = ax[0])
plt.pie(percentage, labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## Most customers take cash loans

# %% [markdown]
# ## Column : Gender

# %%
info_of_cat("GENDER")
# Out:
# Unique values in GENDER are: ['M' 'F' 'XNA']
# Mode of GENDER is F
# Number of missing values in GENDER is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of gender")                  # Set the title of the graph
percentage = data["GENDER"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(data["GENDER"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = data["GENDER"], ax = ax[0])
plt.pie(percentage, labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## Majority of the customers are female

# %% [markdown]
# ## Column : Car

# %%
info_of_cat("Car")
# Out:
# Unique values in Car are: ['N' 'Y']
# Mode of Car is N
# Number of missing values in Car is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Cars")                  # Set the title of the graph
percentage = data["Car"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(data["Car"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = data["Car"], ax = ax[0])
plt.pie(percentage, labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## About 66% of the customers dont own a car

# %% [markdown]
# ## Column : House

# %%
info_of_cat("House")
# Out:
# Unique values in House are: ['Y' 'N']
# Mode of House is Y
# Number of missing values in House is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("House")                  # Set the title of the graph
percentage = data["House"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(data["House"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = data["House"], ax = ax[0])
plt.pie(percentage, labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## Majority of the customers own a house (70%)

# %% [markdown]
# ## Column : CNT_CHILDREN

# %%
info_of_cat("CNT_CHILDREN")
# Out:
# Unique values in CNT_CHILDREN are: [ 0  1  2  3  4  7  5  6  8  9 11 12]
# Mode of CNT_CHILDREN is 0
# Number of missing values in CNT_CHILDREN is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Children")                  # Set the title of the graph
percentage = data["CNT_CHILDREN"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(data["CNT_CHILDREN"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = data["CNT_CHILDREN"], ax = ax[0])
plt.pie(percentage, labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %%
# We are replacing the remaning data with the mean 
mean = int(data["CNT_CHILDREN"].mean())
# accessing the data higher than 2
x = data[data["CNT_CHILDREN"] > 2].index
for index in x:
    data.loc[index, "CNT_CHILDREN"] = mean

# %%
info_of_cat("CNT_CHILDREN")
# Out:
# Unique values in CNT_CHILDREN are: [0 1 2]
# Mode of CNT_CHILDREN is 0
# Number of missing values in CNT_CHILDREN is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Children")                  # Set the title of the graph
percentage = data["CNT_CHILDREN"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(data["CNT_CHILDREN"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = data["CNT_CHILDREN"], ax = ax[0])
plt.pie(percentage, labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## Most of the customer have 0 children

# %% [markdown]
# ## Column : NAME_TYPE_SUITE

# %%
info_of_cat("NAME_TYPE_SUITE")
# Out:
# Unique values in NAME_TYPE_SUITE are: ['Unaccompanied' 'Family' 'Spouse, partner' 'Children' 'Other_A' nan
#  'Other_B' 'Group of people']
# Mode of NAME_TYPE_SUITE is Unaccompanied
# Number of missing values in NAME_TYPE_SUITE is 405
#
# There are null values in the NAME_TYPE_SUITE column

# %%
NAME_TYPE_SUITE_mode = data.NAME_TYPE_SUITE.mode()[0]
data["NAME_TYPE_SUITE"].fillna(NAME_TYPE_SUITE_mode, inplace = True)

# %%
fig, ax=plt.subplots(1,2,figsize=(16,8))
ax[0].set_title("count of accompanying client")
percentage=data["NAME_TYPE_SUITE"].value_counts()
labels=list(data["NAME_TYPE_SUITE"].value_counts().index)

sns.countplot(x=data["NAME_TYPE_SUITE"], ax=ax[0])
plt.pie(percentage,labels=labels, autopct="%0.2f%%")

plt.show()

# %% [markdown]
# ## Unaccompanied(81%) are more popular followed by family

# %% [markdown]
# # Column : NAME_INCOME_TYPE

# %%
info_of_cat("NAME_INCOME_TYPE")
# Out:
# Unique values in NAME_INCOME_TYPE are: ['Working' 'State servant' 'Commercial associate' 'Pensioner' 'Unemployed'
#  'Student' 'Businessman' 'Maternity leave']
# Mode of NAME_INCOME_TYPE is Working
# Number of missing values in NAME_INCOME_TYPE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("NAME_INCOME_TYPE")                  # Set the title of the graph
percentage = data["NAME_INCOME_TYPE"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(data["NAME_INCOME_TYPE"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = data["NAME_INCOME_TYPE"], ax = ax[0])
plt.pie(percentage, labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## Almost 52% of the clients are working and 23% are commercial associate

# %% [markdown]
# ## Column : NAME_EDUCATION_TYPE

# %%
info_of_cat("NAME_EDUCATION_TYPE")
# Out:
# Unique values in NAME_EDUCATION_TYPE are: ['Secondary / secondary special' 'Higher education' 'Incomplete higher'
#  'Lower secondary' 'Academic degree']
# Mode of NAME_EDUCATION_TYPE is Secondary / secondary special
# Number of missing values in NAME_EDUCATION_TYPE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("NAME_EDUCATION_TYPE")                  # Set the title of the graph
percentage = data["NAME_EDUCATION_TYPE"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(data["NAME_EDUCATION_TYPE"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = data["NAME_EDUCATION_TYPE"], ax = ax[0])
plt.pie(percentage, labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## Secondary/Secondary special are 71% clients and approx. 24.5% Higher education clients are there.

# %% [markdown]
# ## Column : NAME_FAMILY_STATUS

# %%
info_of_cat("NAME_FAMILY_STATUS")
# Out:
# Unique values in NAME_FAMILY_STATUS are: ['Single / not married' 'Married' 'Civil marriage' 'Widow' 'Separated'
#  'Unknown']
# Mode of NAME_FAMILY_STATUS is Married
# Number of missing values in NAME_FAMILY_STATUS is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("NAME_FAMILY_STATUS")                  # Set the title of the graph
percentage = data["NAME_FAMILY_STATUS"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(data["NAME_FAMILY_STATUS"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = data["NAME_FAMILY_STATUS"], ax = ax[0])
plt.pie(percentage, labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## Mostly married clients are popular followed by single/not married

# %% [markdown]
# ## Column : Mobile

# %%
info_of_cat("MOBILE")
# Out:
# Unique values in MOBILE are: [1 0]
# Mode of MOBILE is 1
# Number of missing values in MOBILE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Mobile")                  # Set the title of the graph
percentage = data["MOBILE"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(data["MOBILE"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = data["MOBILE"], ax = ax[0])
plt.pie(percentage, labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## All clients have mobile numbers

# %% [markdown]
# ## Column : OCCUPATION_TYPE

# %%
info_of_cat("OCCUPATION_TYPE")
# Out:
# Unique values in OCCUPATION_TYPE are: ['Laborers' 'Core staff' 'Accountants' 'Managers' nan 'Drivers'
#  'Sales staff' 'Cleaning staff' 'Cooking staff' 'Private service staff'
#  'Medicine staff' 'Security staff' 'High skill tech staff'
#  'Waiters/barmen staff' 'Low-skill Laborers' 'Realty agents' 'Secretaries'
#  'IT staff' 'HR staff']
# Mode of OCCUPATION_TYPE is Laborers
# Number of missing values in OCCUPATION_TYPE is 31224
#
# There are null values in the OCCUPATION_TYPE column

# %%
# Plot the graph-
fig, ax = plt.subplots(figsize= (20,8))
ax = sns.countplot(x = data["OCCUPATION_TYPE"])
ax.set_xticklabels(ax.get_xticklabels(), rotation = 40 , ha = "right") # set_xticklabels is used to set the labels of the x axis
                                                                       # ax.get_xtickslabels() returns all the labels that we need to print
                                                                       # rotation: rotate the xlabels at angle provided, and
                                                                       # ha: Horizontal axis:-> how you want to keep it. can be changed to center, left, right
count = len(data["OCCUPATION_TYPE"])                                     # counting the number of rows in whole dataset
for bar in ax.patches:                                                 # ax.patches returns the rectange object from matplotlib 
    percentage = f"{round((bar.get_height()/count)*100, 2)} %"           # first it calculate the bar heightand then dividing by the number of row(to calculate percentage)
                                                                            # in data and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                                # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                                # get_height: returns height of rectangle bar.
    ax.annotate(percentage, (x, y), ha = "center", va = "top")          # va: Vertical axis: -> top means percentage would bneath the bar head
                                                                        # annotate: used to annotate over objects. here objects are the bars 
plt.show()

# %%
mode = data["OCCUPATION_TYPE"].mode()[0]
data["OCCUPATION_TYPE"].fillna(NAME_TYPE_SUITE_mode, inplace = True)

# %%
# Plot the graph-
fig, ax = plt.subplots(figsize= (20,8))
ax = sns.countplot(x = data["OCCUPATION_TYPE"])
ax.set_xticklabels(ax.get_xticklabels(), rotation = 40 , ha = "right") # set_xticklabels is used to set the labels of the x axis
                                                                       # ax.get_xtickslabels() returns all the labels that we need to print
                                                                       # rotation: rotate the xlabels at angle provided, and
                                                                       # ha: Horizontal axis:-> how you want to keep it. can be changed to center, left, right
count = len(data["OCCUPATION_TYPE"])                                     # counting the number of rows in whole dataset
for bar in ax.patches:                                                 # ax.patches returns the rectange object from matplotlib 
    percentage = f"{round((bar.get_height()/count)*100, 2)} %"           # first it calculate the bar heightand then dividing by the number of row(to calculate percentage)
                                                                            # in data and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                                # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                                # get_height: returns height of rectangle bar.
    ax.annotate(percentage, (x, y), ha = "center", va = "top")          # va: Vertical axis: -> top means percentage would bneath the bar head
                                                                        # annotate: used to annotate over objects. here objects are the bars 
plt.show()

# %% [markdown]
# ## Labours client(18%) and sales staff(10.38%) follwed by core-staff

# %% [markdown]
# ## Column : CNT_FAM_MEMBERS

# %%
info_of_cat("CNT_FAM_MEMBERS")
# Out:
# Unique values in CNT_FAM_MEMBERS are: [ 1.  2.  3.  4.  5.  6.  9.  7.  8. 10. 13. nan 14.]
# Mode of CNT_FAM_MEMBERS is 2.0
# Number of missing values in CNT_FAM_MEMBERS is 1
#
# There are null values in the CNT_FAM_MEMBERS column

# %%
mode = data["CNT_FAM_MEMBERS"].mode()[0]
data["CNT_FAM_MEMBERS"].fillna(NAME_TYPE_SUITE_mode, inplace = True)

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("CNT_FAM_MEMBERS")                  # Set the title of the graph
percentage = data["CNT_FAM_MEMBERS"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(data["CNT_FAM_MEMBERS"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = data["CNT_FAM_MEMBERS"], ax = ax[0])
plt.pie(percentage, labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## Majority of clients have total 2 family members follwed by single client in family

# %% [markdown]
# ## Column : APPLICATION_DAY

# %%
info_of_cat("APPLICATION_DAY")
# Out:
# Unique values in APPLICATION_DAY are: ['WEDNESDAY' 'MONDAY' 'THURSDAY' 'SUNDAY' 'SATURDAY' 'FRIDAY' 'TUESDAY']
# Mode of APPLICATION_DAY is TUESDAY
# Number of missing values in APPLICATION_DAY is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("APPLICATION_DAY")                  # Set the title of the graph
percentage = data["APPLICATION_DAY"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(data["APPLICATION_DAY"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = data["APPLICATION_DAY"], ax = ax[0])
plt.pie(percentage, labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## Except sunday all days are having almost same number of applications

# %% [markdown]
# ## Column : TOTAL_DOC_SUBMITTED

# %%
info_of_cat("TOTAL_DOC_SUBMITTED")
# Out:
# Unique values in TOTAL_DOC_SUBMITTED are: [1 0 2 3 4]
# Mode of TOTAL_DOC_SUBMITTED is 1
# Number of missing values in TOTAL_DOC_SUBMITTED is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("TOTAL_DOC_SUBMITTED")                  # Set the title of the graph
percentage = data["TOTAL_DOC_SUBMITTED"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(data["TOTAL_DOC_SUBMITTED"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = data["TOTAL_DOC_SUBMITTED"], ax = ax[0])
plt.pie(percentage, labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## Almost 88% of the clients submitted only 1 documents

# %%
def info_of_numerical(col):
    print(f"The mean of the {col} is {data[col].mean()}")
    print(f"The median of the {col} is {data[col].median()}")
    print(f"The mode of the {col} is {data[col].mode()[0]}")
    print(f"The standard deviation of the {col} is {data[col].std()}")
    print(f"Number of missing values in the {col} is {data[col].isnull().sum()}")

# %% [markdown]
# # Column : AMT_CREDIT

# %%
info_of_numerical("AMT_CREDIT")
# Out:
# The mean of the AMT_CREDIT is 599003.4465
# The median of the AMT_CREDIT is 513040.5
# The mode of the AMT_CREDIT is 450000.0
# The standard deviation of the AMT_CREDIT is 402051.9591213264
# Number of missing values in the AMT_CREDIT is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = data["AMT_CREDIT"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = data["AMT_CREDIT"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %%
data["AMT_CREDIT"].quantile(.95)
data["AMT_CREDIT"]=data["AMT_CREDIT"].clip(upper=data["AMT_CREDIT"].quantile(0.95))

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = data["AMT_CREDIT"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = data["AMT_CREDIT"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %% [markdown]
# ## Many outliers are there and amout of load credited are have almost right skewded

# %% [markdown]
# ## Column : DAYS_EMPLOYED

# %%
info_of_numerical("DAYS_EMPLOYED")
# Out:
# The mean of the DAYS_EMPLOYED is 63292.22206
# The median of the DAYS_EMPLOYED is -1219.0
# The mode of the DAYS_EMPLOYED is 365243
# The standard deviation of the DAYS_EMPLOYED is 140839.69729599176
# Number of missing values in the DAYS_EMPLOYED is 0

# %%
df1=data["DAYS_EMPLOYED"]
df1_emp=pd.DataFrame(df1)
df1_emp
# Out:
#        DAYS_EMPLOYED
# 0               -637
# 1              -1188
# 2               -225
# 3              -3039
# 4              -3038
# ...              ...
# 99995           -232
# 99996           -182
# 99997          -4805
# 99998           -340
# 99999          -3230
#
# [100000 rows x 1 columns]

# %%
df1_emp[df1_emp["DAYS_EMPLOYED"]<0]=0
df1_emp[df1_emp["DAYS_EMPLOYED"]>1]=1
df1_emp
# Out:
#        DAYS_EMPLOYED
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 99995              0
# 99996              0
# 99997              0
# 99998              0
# 99999              0
#
# [100000 rows x 1 columns]

# %%
sns.histplot(x = df1_emp["DAYS_EMPLOYED"])
# Out:
# <AxesSubplot:xlabel='DAYS_EMPLOYED', ylabel='Count'>

# %% [markdown]
# # BIVARIENT ANALYSIS

# %% [markdown]
# ## Gender and target client

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "TARGET", hue = "GENDER", data = data)
plt.show()

# %% [markdown]
# ## Females are mostly targeted clients

# %% [markdown]
# ## Target clients having car

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "TARGET", hue = "Car", data = data)
plt.show()

# %% [markdown]
# ## In the Targeted clients Majority of the them do not own a car

# %% [markdown]
# ## Target clients having House

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "TARGET", hue = "House", data = data)
plt.show()

# %% [markdown]
# ## In the Targeted clients Majority of the them do own a house

# %% [markdown]
# ## Target clients have count of children

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "TARGET", hue = "CNT_CHILDREN", data = data)
plt.show()

# %% [markdown]
# ## In the Targeted clients having no children is popular followed by 1 children

# %% [markdown]
# ## Target clients having income type Suite

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "TARGET", hue = "NAME_TYPE_SUITE", data = data)
plt.show()

# %% [markdown]
# ## In the Targeted clients Unaccompanied is popular followed by Family

# %% [markdown]
# ## Target clients Level of highest education achieved

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "TARGET", hue = "NAME_EDUCATION_TYPE", data = data)
plt.show()

# %% [markdown]
# ## Most target clients have completed secondary education

# %% [markdown]
# ## Family status of the target client

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "TARGET", hue = "NAME_FAMILY_STATUS", data = data)
plt.show()

# %% [markdown]
# ## Most of the clients are married

# %% [markdown]
# ## What kind of occupation does the target client have

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "TARGET", hue = "OCCUPATION_TYPE", data = data)
plt.show()

# %% [markdown]
# ## How many family members does target client have

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "TARGET", hue = "CNT_FAM_MEMBERS", data = data)
plt.show()

# %% [markdown]
# ## Relationship between Target and Amount credit

# %%
fig, ax = plt.subplots(1, 2, figsize = (20,8 ))
sns.histplot(x = data['AMT_CREDIT'], hue = data['TARGET'], ax = ax[0])
sns.boxplot(y = data['AMT_CREDIT'], x = data['TARGET'], ax = ax[1])
plt.show()

# %% [markdown]
# ## Amount credited to non defaulter is high

# %% [markdown]
# ## Loan amount credited according to gender

# %%
fig, ax = plt.subplots(1, 2, figsize = (20,8 ))
sns.histplot(x = data['AMT_CREDIT'], hue = data['GENDER'], ax = ax[0])
sns.boxplot(y = data['AMT_CREDIT'], x = data['GENDER'], ax = ax[1])
plt.show()

# %% [markdown]
# ## gender does not have much effect on amount credit

# %% [markdown]
# ## Multivariate

# %% [markdown]
# ## Targeted Clients got amount credit having car, house who are female and 3 in family,2 in family, single in family

# %%
fig,ax=plt.subplots(figsize=(20,8))
sns.boxplot(y=data["AMT_CREDIT"],x=data["CNT_FAM_MEMBERS"]);

# %% [markdown]
# ## Targeted Clients who are female and have 2 in family has higher chances to get more credit amount

# %% [markdown]
# ## Targeted Clients got amount credit having car, house who are Male and 3 in family,2 in family, single in family

# %%
df3=data.loc[(data.TARGET==1)&(data.Car=="Y")&(data["GENDER"]=="M")&(data["CNT_FAM_MEMBERS"]==3.0)]
df2=data.loc[(data.TARGET==1)&(data.Car=="Y")&(data["GENDER"]=="M")&(data["CNT_FAM_MEMBERS"]==2.0)]
df1=data.loc[(data.TARGET==1)&(data.Car=="Y")&(data["GENDER"]=="M")&(data["CNT_FAM_MEMBERS"]==1.0)]

# %%
fig,ax=plt.subplots(1,3,figsize=(20,8))
sns.boxplot(y=df1["AMT_CREDIT"],x=df1["CNT_FAM_MEMBERS"],ax=ax[0])
sns.boxplot(y=df2["AMT_CREDIT"],x=df2["CNT_FAM_MEMBERS"],ax=ax[1])
sns.boxplot(y=df3["AMT_CREDIT"],x=df3["CNT_FAM_MEMBERS"],ax=ax[2])
# Out:
# <AxesSubplot:xlabel='CNT_FAM_MEMBERS', ylabel='AMT_CREDIT'>

# %% [markdown]
# ## Targeted Clients who are Male and have 2 in family has higher chances to get more credit amount followed by 3 in family

# %% [markdown]
# ## Targeted clients who have education and do not have car and house gets the loan approved

# %%
df3=data.loc[(data.TARGET==1)&(data.Car=="N")&(data["NAME_EDUCATION_TYPE"])&(data["NAME_EDUCATION_TYPE"]=="Secondary / secondary special")]
df2=data.loc[(data.TARGET==1)&(data.Car=="N")&(data["NAME_EDUCATION_TYPE"])&(data["NAME_EDUCATION_TYPE"]=='Higher education')]
df1=data.loc[(data.TARGET==1)&(data.Car=="N")&(data["NAME_EDUCATION_TYPE"])&(data["NAME_EDUCATION_TYPE"]=='Academic degree')]

# %%
fig,ax=plt.subplots(1,3,figsize=(20,8))
sns.boxplot(y=df1["AMT_CREDIT"],x=df1["NAME_EDUCATION_TYPE"],ax=ax[0])
sns.boxplot(y=df2["AMT_CREDIT"],x=df2["NAME_EDUCATION_TYPE"],ax=ax[1])
sns.boxplot(y=df3["AMT_CREDIT"],x=df3["NAME_EDUCATION_TYPE"],ax=ax[2])
# Out:
# <AxesSubplot:xlabel='NAME_EDUCATION_TYPE', ylabel='AMT_CREDIT'>

# %% [markdown]
# ## Targeted clients who have higer education and do not have car and house have more chance of getting amount credit

# %% [markdown]
# ## Insights

# %% [markdown]
# If the client have car, house and other assets are having more chance of getting loan amount credit into there account.
# The Clients who have higher education and are female can also increase thier chance of getting loan amount.
# The number of family members also affects the loan credit amount

# %% [markdown]
# ## Recommendation

# %% [markdown]
# ## If the applicant is a female having higher education and have a car and a house with total count of family members not greater than 3 will be preffered for the loan
